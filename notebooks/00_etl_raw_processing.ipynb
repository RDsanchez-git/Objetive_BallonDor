# %% [markdown]
# # **📚 Diccionario de Datos: Big 5 Leagues (FBREF/StatsBomb)**
#
# Este documento detalla la nomenclatura estandarizada (`snake_case`) utilizada en el dataset `fbref_big5_players_24_25_clean.csv` tras el proceso de ETL.
#
# ---
#
# ## 1. Identificación y Metadatos
# *Variables categóricas y dimensionales para filtrar, agrupar y ordenar.*
#
# | Variable (DB) | Origen (FBREF) | Descripción e Interpretación |
# | :--- | :--- | :--- |
# | `player_name` | Player | Nombre único del jugador. |
# | `nation` | Nation | Nacionalidad (código FIFA). |
# | `main_position_group` | Pos_Primary | Posición simplificada (DF=Defensa, MF=Medio, FW=Delantero, GK=Portero). |
# | `squad` | Squad | Equipo actual. |
# | `league_id` | Comp | Liga de competencia (ej. Premier League, La Liga). |
# | `age` | Age | Edad al comienzo de la temporada. |
# | `born` | Born | Año de nacimiento. |
# | `record_type` | (Custom) | Indica si el registro es 'Total' (temporada completa) o 'Parcial' (por equipo). |
# | `team_order` | *Metadata* | **Orden del Equipo.** Variable auxiliar de índice. *Uso: Se utiliza frecuentemente para mantener el orden alfabético o de clasificación de los equipos en visualizaciones.* |
# | `rank` | Rk | **Ranking / Índice.** Número de fila original en la tabla de FBref. *Interpretación: Irrelevante estadísticamente, útil solo para trazabilidad o verificar el orden original de carga.* |
#
# ## 2. Tiempo de Juego
# *Volumen de participación. Fundamental para normalizar métricas.*
#
# | Variable (DB) | Origen (FBREF) | Descripción e Interpretación |
# | :--- | :--- | :--- |
# | `matches_played` | MP | Partidos totales jugados (Titular + Suplente). |
# | `starts` | Starts | Partidos iniciados como titular. |
# | `minutes_played` | Min | Total de minutos disputados. |
# | `nineties` | 90s | Minutos jugados divididos por 90 (Partidos equivalentes). |
# | `minutes_per_match` | Mn/MP | Promedio de minutos por partido jugado. |
# | `minutes_pct` | Min% | Porcentaje del total de minutos posibles que jugó. |
# | `minutes_per_start` | Mn/Start | Promedio de minutos jugados cada vez que fue titular. |
# | `matches_completed` | Compl | Partidos jugados completos (sin ser sustituido). |
# | `matches_subbed_in` | Subs | Partidos en los que ingresó desde el banco. |
# | `minutes_per_sub` | Mn/Sub | Promedio de minutos jugados cuando ingresó como suplente. |
# | `unused_sub` | unSub | Partidos en los que estuvo en el banco y no ingresó. |
# | `points_per_match` | PPM | Puntos promedio obtenidos por el equipo en los partidos que jugó. |
#
# ## 3. Ataque y Finalización (Shooting)
# *Métricas de producción ofensiva directa.*
#
# | Variable (DB) | Origen (FBREF) | Descripción e Interpretación |
# | :--- | :--- | :--- |
# | `goals` | Gls | Goles totales marcados. |
# | `assists` | Ast | Asistencias totales realizadas. |
# | `goals_assists` | G+A | Suma directa de goles y asistencias. |
# | `pk_goals` | PK | Goles marcados de penal. |
# | `pk_attempts` | PKatt | Penales lanzados en total (marcados o fallados). |
# | `xg` | xG | Goles Esperados (Probabilidad acumulada de gol). |
# | `xag`| xAG | **Expected Assisted Goals (Post-Disparo).** El valor de xG del remate que resultó del pase. *Interpretación: Indica cuánto contribuyó el pase a la generación de una ocasión de gol real. Se usa para sumar con el xG propio (xG + xAG).* |
# | `npxg` | npxG | Goles Esperados excluyendo penales. |
# | `shots_total` | Sh | Total de disparos realizados (incluye bloqueados). |
# | `shots_on_target` | SoT | Disparos que fueron al arco (a puerta). |
# | `shots_on_target_pct` | SoT% | Porcentaje de disparos que van al arco. |
# | `goals_per_shot` | G/Sh | Goles por cada disparo (Tasa de conversión de tiro). |
# | `goals_per_sot` | G/SoT | Goles por cada disparo al arco (Efectividad a puerta). |
# | `avg_shot_distance` | Dist | Distancia promedio de los disparos al arco (yardas). |
# | `free_kick_shots` | FK | Disparos realizados desde tiros libres directos. |
# | `non_penalty_goals` | G-PK | Goles marcados excluyendo los penales. |
# | `non_penalty_goals_assists` | G+A-PK | Suma de goles (sin penales) y asistencias. |
# | `expected_goals_assists` | xG+xAG | Suma total de Goles Esperados (xG) y Asistencias Esperadas (xAG). |
# | `npxg_plus_xa` | npxG+xAG | Suma de xG (sin penales) y Asistencias Esperadas. |
# | `goals_minus_xg` | G-xG | Diferencia entre Goles reales y xG (Mide suerte o capacidad de finalización). |
# | `np_goals_minus_npxg` | np:G-xG | Diferencia entre Goles sin penales y npxG (Finalización en juego abierto). |
# | `npxg_per_shot` | npxG/Sh | xG promedio por disparo (Mide la calidad de selección de tiro). |
# | `shots_p90` | Sh/90 | Promedio de disparos realizados por cada 90 minutos. |
# | `shots_on_target_p90` | SoT/90 | Promedio de disparos al arco por cada 90 minutos. |
#
# ## 4. Creación de Tiros (SCA/GCA)
# *Quién genera el peligro (Playmaking avanzado).*
#
# | Variable (DB) | Origen (FBREF) | Descripción e Interpretación |
# | :--- | :--- | :--- |
# | `sca` | SCA | **Shot-Creating Actions.** Acciones ofensivas (pases, regates, faltas) que conducen directamente a un tiro. |
# | `sca_p90` | SCA90 | Promedio de SCA por cada 90 minutos. |
# | `gca` | GCA | **Goal-Creating Actions.** Acciones ofensivas que conducen directamente a un gol. |
# | `gca_p90` | GCA90 | Promedio de GCA por cada 90 minutos. |
# | `sca_pass_live` | PassLive | SCA generadas por un pase en juego vivo (balón en movimiento). |
# | `sca_pass_dead` | PassDead | SCA generadas por un pase a balón parado (tiros libres, córners, saques de banda). |
# | `sca_dribble` | TO | SCA generadas tras un regate exitoso (Take-On) que termina en tiro. |
# | `sca_defense` | Def | SCA generadas tras una acción defensiva (recuperación, bloqueo, etc.) que deriva en tiro. |
#
# ## 5. Pases y Progresión
# *Construcción de juego y avance del balón.*
#
# | Variable (DB) | Origen (FBREF) | Descripción e Interpretación |
# | :--- | :--- | :--- |
# | `progressive_passes` | PrgP | **Pases Progresivos.** Pases completados que mueven el balón al menos 10 yardas hacia la portería rival (o entran al área penal). Excluye pases desde el 40% defensivo. |
# | `key_passes` | KP | **Pases Clave.** Pases que conducen directamente a un tiro de un compañero. |
# | `passes_penalty_area` | PPA | Pases completados dentro del área penal de 18 yardas (excluye balón parado). |
# | `crosses_penalty_area` | CrsPA | Centros completados dentro del área penal de 18 yardas. |
# | `passes_completed` | Cmp | Total de pases completados con éxito. |
# | `passes_attempted` | Att | Total de pases intentados. |
# | `pass_completion_pct` | Cmp% | Porcentaje de acierto en el pase (Cmp / Att). |
# | `pass_total_distance` | TotDist | Distancia total (en yardas) recorrida por los pases completados (cualquier dirección). |
# | `pass_progressive_distance` | PrgDist | Distancia total (en yardas) que el balón viajó *hacia la portería rival* en pases completados. |
# | `xa` | xA | **Expected Assists (Pre-Disparo).** Probabilidad de que el pase se convierta en gol. *Interpretación: Mide la capacidad del jugador para poner balones peligrosos, independientemente de si el compañero logra rematar o no.* |
# | `assists_minus_xa` | A-xAG | Diferencia entre Asistencias reales y xAG. (Positivo = compañeros definen bien; Negativo = compañeros fallan las chances creadas). |
#
# ## 6. Posesión y Regate
# *Habilidad individual con el balón.*
#
# | Variable (DB) | Origen (FBREF) | Descripción e Interpretación |
# | :--- | :--- | :--- |
# || `touches` | Touches | Total de veces que el jugador tocó el balón. |
# | `touches_def_pen_area` | Def Pen | Toques de balón dentro del área penal propia (Defensiva). |
# | `touches_att_pen_area` | Att Pen | Toques de balón dentro del área penal rival (Ofensiva). |
# | `carries` | Carries | **Conducciones.** Número de veces que el jugador controla el balón con los pies. |
# | `progressive_carries` | PrgC | **Conducciones Progresivas.** Conducciones que mueven el balón al menos 10 yardas hacia la meta rival (o entran al área). |
# | `progressive_runs` | PrgR | **Pases Progresivos Recibidos.** Número de veces que el jugador recibe un pase progresivo. (Mide la capacidad de desmarque). |
# | `carries_penalty_area` | CPA | Conducciones que entran al área penal rival de 18 yardas. |
# | `miscontrols` | Mis | **Errores de Control.** Fallos al intentar controlar el balón (pérdida no forzada). |
# | `dispossessed` | Dis | **Desposeídos.** Veces que pierde el balón al ser tackleado por un rival (pérdida forzada). |
# | `passes_received` | Rec | Total de pases recibidos con éxito. |
# | `dribbles_completed` | Succ | **Regates Completados.** Veces que el jugador supera a un defensor con un regate (Take-ons). |
# | `dribble_success_pct` | Succ% | Porcentaje de regates intentados que fueron exitosos. |
# | `dribbles_tackled` | Tkld | **Regates Fallidos (Tackleados).** Veces que el jugador fue detenido por un defensor al intentar regatear. |
# | `dribbles_tackled_pct` | Tkld% | Porcentaje de veces que el jugador perdió el balón intentando un regate. |
#
# ## 7. Defensa
# *Recuperación del balón y presión.
#
# | Variable (DB) | Origen (FBREF) | Descripción e Interpretación |
# | :--- | :--- | :--- |
# | `tackles_total` | Tkl | **Entradas Totales.** Número total de entradas (tackles) realizadas a rivales. |
# | `tackles_won` | TklW | **Entradas Ganadas.** Entradas donde el equipo recuperó la posesión del balón. |
# | `interceptions` | Int | **Intercepciones.** Cortes de pase anticipando la jugada y recuperando el balón. |
# | `blocks` | Blocks | **Bloqueos.** Total de veces que bloqueó el balón (disparos + pases). |
# | `clearances` | Clr | **Despejes.** Acciones para alejar el balón de la zona de peligro defensiva. |
# | `errors_leading_to_goal` | Err | **Errores Graves.** Fallos defensivos directos que resultaron en un gol del rival. |
# | `ball_recoveries` | Recov | **Recuperaciones.** Balones sueltos recuperados (sin disputa física directa). |
# | `tackles_interceptions` | Tkl+Int | Suma de entradas e intercepciones (Métrica general de actividad defensiva). |
# | `tackles_def_3rd` | Def 3rd | Entradas realizadas en el tercio defensivo (cerca de propia área). |
# | `tackles_mid_3rd` | Mid 3rd | Entradas realizadas en el tercio medio del campo. |
# | `tackles_att_3rd` | Att 3rd | Entradas realizadas en el tercio ofensivo (Presión alta). |
# | `challenge_tackles_pct` | Tkl% | Porcentaje de regates rivales detenidos exitosamente (vs. ser regateado). |
# | `challenges_lost` | Lost | **Regateado.** Veces que un rival superó al jugador con un regate. |
# | `blocks_passes` | Pass | **Pases Bloqueados.** Veces que interceptó la trayectoria de un pase con el cuerpo. |
#
#
# ## 8. Porteros (GK)
# *Métricas específicas de arco.*
#
# | Variable (DB) | Origen (FBREF) | Descripción e Interpretación |
# | :--- | :--- | :--- |
# | `goals_against` | GA | **Goles en Contra.** Goles recibidos en total. |
# | `goals_against_p90` | GA90 | Promedio de goles recibidos por cada 90 minutos. |
# | `shots_on_target_against` | SoTA | **Tiros al Arco Enfrentados.** Total de disparos a puerta que recibió el portero. |
# | `saves` | Saves | **Atajadas.** Número de disparos al arco detenidos por el portero. |
# | `save_pct` | Save% | **Porcentaje de Atajadas.** (Atajadas / Tiros al Arco Enfrentados). |
# | `clean_sheets` | CS | **Vallas Invictas.** Partidos completos sin recibir goles. |
# | `clean_sheet_pct` | CS% | Porcentaje de partidos jugados que terminaron en valla invicta. |
# | `wins` | W | Partidos ganados. |
# | `draws` | D | Partidos empatados. |
# | `losses` | L | Partidos perdidos. |
# | `pk_allowed` | PKA | Penales que terminaron en gol. |
# | `pk_saved` | PKsv | Penales atajados por el portero. |
# | `pk_missed` | PKm | Penales desviados por el rival (fuera o al palo, sin intervención del GK). |
# | `psxg` | PSxG | **Post-Shot Expected Goals.** xG calculado *después* del impacto. Mide qué tan difícil de atajar fue el tiro (basado en colocación y potencia). |
# | `psxg_per_sot` | PSxG/SoT | PSxG promedio por tiro al arco. (Mide la dificultad promedio de los tiros que enfrenta). |
# | `psxg_plus_minus` | PSxG+/- | **Goles Prevenidos.** (PSxG - Goles Reales). Positivo = Atajó más de lo esperado (Salvador). Negativo = Recibió goles "atajables". |
# | `launch_pct` | Launch% | Porcentaje de pases (excluyendo saques de meta) que fueron lanzados largos (>40 yardas). |
# | `avg_pass_length` | AvgLen | Longitud promedio de los pases del portero (en yardas). |
# | `crosses_stopped` | Stp | **Centros Cortados.** Centros al área que el portero interceptó exitosamente. |
# | `crosses_stopped_pct` | Stp% | Porcentaje de centros enfrentados que fueron cortados. |
# | `def_actions_outside_box` | #OPA | **Acciones Defensivas Fuera del Área.** (Sweeper Keeper). Despejes o entradas fuera del área penal. |
# | `def_actions_outside_box_p90` | #OPA/90 | Promedio de acciones defensivas fuera del área por 90 min. |
# | `avg_keeper_sweeper_dist` | AvgDist | Distancia promedio desde la línea de gol a la que realiza acciones defensivas. |
# | `gk_passes_attempted_launch` | Att (GK) | Intentos de pase largo (Lanzamientos >40 yardas). |
# | `gk_throws` | Thr | Saques realizados con la mano. |
# | `gk_crosses_faced` | Opp | Total de centros rivales al área enfrentados. |
#
# ## 9. Impacto en Equipo (On/Off)
# *Rendimiento del equipo con el jugador en cancha.*
#
# | Variable (DB) | Origen (FBREF) | Descripción e Interpretación |
# | :--- | :--- | :--- |
# | `on_goals_for` | onG | **Goles a Favor (En Cancha).** Goles que marcó el equipo mientras el jugador estaba jugando. |
# | `on_goals_against` | onGA | **Goles en Contra (En Cancha).** Goles que recibió el equipo mientras el jugador estaba jugando. |
# | `plus_minus` | +/- | **Plus/Minus (+/-).** Diferencia de goles (A favor - En contra) con el jugador en cancha. |
# | `plus_minus_p90` | +/-90 | **Plus/Minus por 90.** Diferencia de goles promedio por cada 90 minutos jugados. |
# | `plus_minus_on_off` | On-Off | **Impacto Neto (On-Off).** La diferencia del rendimiento del equipo CON el jugador menos el rendimiento SIN el jugador. (Positivo = El equipo juega mejor con él). |
# | `on_xg_for` | onxG | **xG a Favor (En Cancha).** Goles Esperados generados por el equipo con el jugador en cancha. |
# | `on_xg_against` | onxGA | **xG en Contra (En Cancha).** Goles Esperados concedidos por el equipo con el jugador en cancha. |
# | `xg_plus_minus` | xG+/- | **xG Plus/Minus.** Diferencia de xG (xG Favor - xG Contra) con el jugador en cancha. |
# | `xg_plus_minus_p90` | xG+/-90 | **xG Plus/Minus por 90.** Diferencia de xG promedio por cada 90 minutos. (Suele ser un indicador más predictivo del talento real que el +/- de goles). |
#
# ## 10. Disciplina y Eventos Negativos
# *Tarjetas, faltas y errores críticos.*
#
# | Variable (DB) | Origen (FBREF) | Descripción e Interpretación |
# | :--- | :--- | :--- |
# | `yellow_cards` | CrdY | Tarjetas amarillas acumuladas. |
# | `red_cards` | CrdR | Tarjetas rojas acumuladas. |
# | `second_yellow_card` | 2CrdY | Segunda amarilla en un mismo partido (expulsión). |
# | `fouls_committed` | Fls | Faltas cometidas. |
# | `fouls_drawn` | Fld | Faltas recibidas (generadas a favor). |
# | `offsides` | Off | Fueras de juego (Offsides) cobrados al jugador. |
# | `pk_won` | PKwon | Penales generados a favor (por falta o mano). |
# | `pk_conceded` | PKcon | Penales cometidos (defensa). |
# | `own_goals` | OG | Goles en contra (autogoles). |
#
# ## 11. Juego Aéreo
# *Disputas del balón por arriba.*
#
# | Variable (DB) | Origen (FBREF) | Descripción e Interpretación |
# | :--- | :--- | :--- |
# | `aerials_won` | Won | Duelos aéreos ganados. |
# | `aerials_won_pct` | Won% | % de éxito en duelos aéreos (Won / (Won + Lost)). |
#
# ## 12. Residual
# *Variables desconocidas*
#
# | Variable (DB) | Origen (FBREF) | Descripción |
# | :--- | :--- | :--- |
# | `unknown_p90` | /90 | **Artefacto de Scraping.** Generalmente es una columna residual proveniente del encabezado de la tabla original. *Interpretación: Verificar si está vacía; usualmente no contiene datos y debe eliminarse.* |

# %%
# 01_data_cleaning.ipynb
# ETL MASTER V6: ELITE MAPPING INTEGRATION

import pandas as pd
import numpy as np

# ==============================================================================
# 1. CONFIGURACIÓN
# ==============================================================================
INPUT_FILE  = '../services/ingestion/data_drop/fbref_big5_players_24_25_raw.csv'
OUTPUT_FILE = '../services/ingestion/data_drop/fbref_big5_players_24_25_clean.csv'

# TU MAPEO MAESTRO (COMPLETO)
db_mapping = {
    # --- IDENTIFICACIÓN ---
    'Player': 'player_name', 'Nation': 'nation', 'Pos_Primary': 'main_position_group', 
    'Squad': 'squad', 'Comp': 'league_id', 'Age': 'age', 'Born': 'born',
    'Registro_Tipo': 'record_type', 'Team_Order': 'team_order', 'Rk': 'rank',
    
    # --- TIEMPO DE JUEGO ---
    'MP': 'matches_played', 'Starts': 'starts', 'Min': 'minutes_played', '90s': 'nineties',
    'Mn/MP': 'minutes_per_match', 'Min%': 'minutes_pct', 'Mn/Start': 'minutes_per_start',
    'Compl': 'matches_completed', 'Subs': 'matches_subbed_in', 'Mn/Sub': 'minutes_per_sub',
    'unSub': 'unused_sub', 'PPM': 'points_per_match',

    # --- ATAQUE Y GOLES ---
    'Gls': 'goals', 'Ast': 'assists', 'G+A': 'goals_assists',
    'PK': 'pk_goals', 'PKatt': 'pk_attempts',
    'xG': 'xg', 'npxG': 'npxg', 'xAG': 'xag',
    'Sh': 'shots_total', 'SoT': 'shots_on_target', 'SoT%': 'shots_on_target_pct',
    'G/Sh': 'goals_per_shot', 'G/SoT': 'goals_per_sot', 'Dist': 'avg_shot_distance',
    'FK': 'free_kick_shots',
    # Métricas compuestas
    'G-PK': 'non_penalty_goals', 'G+A-PK': 'non_penalty_goals_assists',
    'xG+xAG': 'expected_goals_assists', 'npxG+xAG': 'npxg_plus_xa',
    'G-xG': 'goals_minus_xg', 'np:G-xG': 'np_goals_minus_npxg',
    'npxG/Sh': 'npxg_per_shot', 'Sh/90': 'shots_p90', 'SoT/90': 'shots_on_target_p90',
    
    # --- CREACIÓN (SCA/GCA) ---
    'SCA': 'sca', 'SCA90': 'sca_p90',
    'GCA': 'gca', 'GCA90': 'gca_p90',
    'PassLive': 'sca_pass_live', 'PassDead': 'sca_pass_dead',
    'TO': 'sca_dribble', 'Def': 'sca_defense', 

    # --- PASES (GENERAL) ---
    'PrgP': 'progressive_passes', 'KP': 'key_passes', 
    'PPA': 'passes_penalty_area', 'CrsPA': 'crosses_penalty_area',
    'Cmp': 'passes_completed', 'Att': 'passes_attempted', 'Cmp%': 'pass_completion_pct',
    'TotDist': 'pass_total_distance', 'PrgDist': 'pass_progressive_distance',
    'xA': 'xa', 'A-xAG': 'assists_minus_xa',
    
    # --- PASES (TIPOS) ---
    'Live': 'passes_live', 'Dead': 'passes_dead',
    'TB': 'passes_through_balls', 'Sw': 'passes_switches',
    'Crs': 'passes_crosses', 'TI': 'passes_throw_ins',
    'CK': 'corner_kicks', 'In': 'corner_kicks_in', 
    'Out': 'corner_kicks_out', 'Str': 'corner_kicks_straight',
    '1/3': 'passes_final_third',

    # --- POSESIÓN ---
    'Touches': 'touches', 'Def Pen': 'touches_def_pen_area', 'Att Pen': 'touches_att_pen_area',
    'Carries': 'carries', 'PrgC': 'progressive_carries', 'PrgR': 'progressive_runs',
    'CPA': 'carries_penalty_area', 'Mis': 'miscontrols', 'Dis': 'dispossessed',
    'Rec': 'passes_received',
    'Succ': 'dribbles_completed', 'Succ%': 'dribble_success_pct',
    'Tkld': 'dribbles_tackled', 'Tkld%': 'dribbles_tackled_pct',

    # --- DEFENSA ---
    'Tkl': 'tackles_total', 'TklW': 'tackles_won', 
    'Int': 'interceptions', 'Blocks': 'blocks', 'Clr': 'clearances', 
    'Err': 'errors_leading_to_goal', 'Recov': 'ball_recoveries',
    'Tkl+Int': 'tackles_interceptions', 'Def 3rd': 'tackles_def_3rd',
    'Mid 3rd': 'tackles_mid_3rd', 'Att 3rd': 'tackles_att_3rd',
    'Tkl%': 'challenge_tackles_pct', 'Lost': 'challenges_lost',
    'Pass': 'blocks_passes',

    # --- AÉREO ---
    'Won': 'aerials_won', 'Won%': 'aerials_won_pct',

    # --- IMPACTO (ON/OFF) ---
    'onG': 'on_goals_for', 'onGA': 'on_goals_against',
    '+/-': 'plus_minus', '+/-90': 'plus_minus_p90',
    'On-Off': 'plus_minus_on_off',
    'onxG': 'on_xg_for', 'onxGA': 'on_xg_against',
    'xG+/-': 'xg_plus_minus', 'xG+/-90': 'xg_plus_minus_p90',

    # --- PORTERO ---
    'GA': 'goals_against', 'GA90': 'goals_against_p90',
    'SoTA': 'shots_on_target_against', 
    'Saves': 'saves', 'Save%': 'save_pct', 
    'CS': 'clean_sheets', 'CS%': 'clean_sheet_pct',
    'W': 'wins', 'D': 'draws', 'L': 'losses',
    'PKA': 'pk_allowed', 'PKsv': 'pk_saved', 'PKm': 'pk_missed',
    'PSxG': 'psxg', 'PSxG/SoT': 'psxg_per_sot', 'PSxG+/-': 'psxg_plus_minus',
    'Launch%': 'launch_pct', 'AvgLen': 'avg_pass_length',
    'Stp': 'crosses_stopped', 'Stp%': 'crosses_stopped_pct',
    '#OPA': 'def_actions_outside_box', '#OPA/90': 'def_actions_outside_box_p90',
    'AvgDist': 'avg_keeper_sweeper_dist',
    'Att (GK)': 'gk_passes_attempted_launch', 'Thr': 'gk_throws', 'Opp': 'gk_crosses_faced',
    
    # --- DISCIPLINA ---
    'CrdY': 'yellow_cards', 'CrdR': 'red_cards', '2CrdY': 'second_yellow_card',
    'Fls': 'fouls_committed', 'Fld': 'fouls_drawn', 
    'PKwon': 'pk_won', 'PKcon': 'pk_conceded', 'OG': 'own_goals', 'Off': 'offsides',

    # --- RESIDUALES ---
    #'/90': 'unknown_p90' # A veces aparece basura parseada como '/90'. Es un "artefacto" o error técnico del proceso de descarga, no una métrica real de fútbol. No utilizar.  
}

print(f">>> INICIANDO ETL V6: CON MAPEO ELITE ({len(db_mapping)} VARIABLES) <<<")

# ==============================================================================
# 2. CARGA
# ==============================================================================
try:
    df = pd.read_csv(INPUT_FILE, encoding='utf-8')
except UnicodeDecodeError:
    df = pd.read_csv(INPUT_FILE, encoding='latin1')
except FileNotFoundError:
    print(f"!!! ERROR: No se encuentra {INPUT_FILE}")
    raise

df.columns = df.columns.str.strip()
print(f"[1/5] Carga inicial: {df.shape}")

# ==============================================================================
# 3. LIMPIEZA ESTRUCTURAL
# ==============================================================================
if 'Rk' in df.columns: df = df[df['Rk'] != 'Rk'].copy()

# Eliminar redundancia
cols_to_drop = [c for c in df.columns if '_stats_' in c]
df.drop(columns=cols_to_drop, inplace=True)

# Limpieza de Strings (Metadatos)
if 'Nation' in df.columns: df['Nation'] = df['Nation'].astype(str).str.split(' ').str[-1]
if 'Comp' in df.columns: df['Comp'] = df['Comp'].astype(str).str.split(' ', n=1).str[1]
if 'Pos' in df.columns: df['Pos_Primary'] = df['Pos'].astype(str).str.split(',').str[0]

# ==============================================================================
# 4. CONVERSIÓN DE TIPOS & FILLNA DINÁMICO
# ==============================================================================
# Identificamos metadatos que NO deben tocarse
meta_cols = ['Rk', 'Player', 'Nation', 'Pos', 'Pos_Primary', 'Squad', 'Comp', 'Age', 'Born']

# Todo lo que esté en tu MAPEO pero NO sea metadato, es métrica numérica
mapped_cols = list(db_mapping.keys())
metric_cols_raw = [c for c in mapped_cols if c in df.columns and c not in meta_cols]

# 1. Convertir a numérico
for col in metric_cols_raw:
    df[col] = pd.to_numeric(df[col], errors='coerce')

# 2. Rellenar Nulos con 0 (Dinámicamente para las 100+ variables)
# Esto evita que 'crosses_stopped' sea NaN en delanteros.
print(f"[2/5] Sanitizando {len(metric_cols_raw)} métricas numéricas...")
df[metric_cols_raw] = df[metric_cols_raw].fillna(0)

# 3. Correcciones específicas para Age/Born

for c in ['Age', 'Born']:
    if c in df.columns: df[c] = pd.to_numeric(df[c], errors='coerce')

# 4. Datos recuperados manualmente para jugadores jóvenes sin registro en FBref
manual_ages = {
    'Olabade Aluko': {'Age': 17, 'Born': 2006},
    'Hannes Behrens': {'Age': 19, 'Born': 2005},
    'Pape Daouda Diongue': {'Age': 18, 'Born': 2006},
    'Jake Evans': {'Age': 15, 'Born': 2008},
    'Fer López': {'Age': 20, 'Born': 2004},
    'Mateus Mane': {'Age': 16, 'Born': 2007},
    'Max Moerstedt': {'Age': 18, 'Born': 2006},
    'Jeremy Monga': {'Age': 15, 'Born': 2009}
}

print(f"[2.1/5] Aplicando correcciones manuales de edad para {len(manual_ages)} jugadores...")

for player, data in manual_ages.items():
    # Buscamos al jugador en el DataFrame
    mask = df['Player'] == player
    
    if mask.any():
        # Inyectamos la edad y año de nacimiento reales
        df.loc[mask, 'Age'] = df.loc[mask, 'Age'].fillna(data['Age'])
        df.loc[mask, 'Born'] = df.loc[mask, 'Born'].fillna(data['Born'])
        print(f"   -> Corregido: {player} (Edad: {data['Age']}, Nacido: {data['Born']})")
    else:
        print(f"   ⚠️ Aviso: No se encontró a {player} en el dataset (quizás nombre diferente?).")

# 5. Correcciones específicas para Jugadores sin nacionalidad
print(f"[2.2/5] Aplicando correcciones manuales de nacionalidad para jugadores específicos")

df['Player'] = df['Player'].astype(str).str.strip()

manual_nations = {
    'Olabade Aluko': 'ENG',
    'Jake Evans': 'ENG',
    'Atakan Karazor': 'TUR',
    'Fer López': 'ESP',
    'Mateus Mane': 'POR',
    'Jeremy Monga': 'GER',
    'Plamedi Nsingi': 'COD'
}

count_nat_fix = 0
for player, nation_code in manual_nations.items():
    # Buscamos al jugador
    mask = df['Player'] == player
    
    if mask.any():
        # ASIGNACIÓN DIRECTA (Más fuerte que fillna)
        # Esto sobrescribe lo que sea que haya ahí (NaN, '', 'Unknown')
        df.loc[mask, 'Nation'] = nation_code
        count_nat_fix += 1
        print(f"   -> Asignado {nation_code} a {player}")
    else:
        print(f"   ⚠️ NO ENCONTRADO: {player}. Verifica acentos o espacios.")

print(f"   -> Total Nacionalidades corregidas: {count_nat_fix}")

# Imputación genérica final
df['Nation'] = df['Nation'].fillna('Unknown')


# ==============================================================================
# 5. LÓGICA DE TRANSFERENCIAS (TOTALES)
# ==============================================================================
print("[3/5] Calculando Totales por Jugador...")

df['Team_Order'] = df.groupby('Player').cumcount() + 1
df['Registro_Tipo'] = 'Parcial'

player_counts = df['Player'].value_counts()
multi_players = player_counts[player_counts > 1].index
df_multi = df[df['Player'].isin(multi_players)].copy()

if not df_multi.empty:
    # Sumar solo las métricas identificadas
    agg_dict = {col: 'sum' for col in metric_cols_raw}
    
    # Metadatos -> First
    meta_existing = [c for c in meta_cols if c in df.columns and c != 'Player']
    agg_dict.update({col: 'first' for col in meta_existing})
    if 'Age' in df.columns: agg_dict['Age'] = 'max'

    df_totals = df_multi.groupby('Player').agg(agg_dict).reset_index()

    # Sanitizar Ratios en Totales (No sumar %)
    ratio_keywords = ['%', '/90', 'Per 90', 'Av', 'Mn/', 'PPM']
    # Buscamos columnas de ratio dentro de las métricas mapeadas
    ratio_cols = [c for c in metric_cols_raw if any(k in c for k in ratio_keywords)]
    
    for col in ratio_cols: df_totals[col] = np.nan

    df_totals['Squad'] = 'COMBINED'
    df_totals['Comp'] = 'Multiple'
    df_totals['Registro_Tipo'] = 'Total'
    df_totals['Team_Order'] = 0
    
    df_final = pd.concat([df, df_totals], ignore_index=True)
else:
    df_final = df.copy()

# ==============================================================================
# 6. ESTANDARIZACIÓN (APLICAR TU MAPEO)
# ==============================================================================
print("[4/5] Aplicando Mapeo Elite (Snake Case)...")

# 1. Renombrar
df_final.rename(columns=db_mapping, inplace=True)

# 2. Filtrar Columnas (Solo nos quedamos con las del mapeo + control)
final_cols_wanted = list(db_mapping.values())
# Añadimos metadatos extra generados si no están en el mapa
extra_cols = ['registro_tipo', 'team_order', 'pos_primary'] 
# (Nota: 'registro_tipo' viene de 'Registro_Tipo' que ya se renombró si estaba en el mapa, 
# pero 'Registro_Tipo' NO estaba en tu mapa original como key, así que lo añadí manualmente abajo)

# Pequeño fix: Asegurar que las columnas de control tengan nombre snake_case si no lo tenían
if 'Registro_Tipo' in df_final.columns: df_final.rename(columns={'Registro_Tipo': 'record_type'}, inplace=True)
if 'Team_Order' in df_final.columns: df_final.rename(columns={'Team_Order': 'team_order'}, inplace=True)
if 'Pos_Primary' in df_final.columns: df_final.rename(columns={'Pos_Primary': 'main_position_group'}, inplace=True)

# Lista final de columnas deseadas (Valores del mapa + controles)
valid_cols = [c for c in df_final.columns if c in db_mapping.values() or c in ['record_type', 'team_order']]

df_export = df_final[valid_cols].copy()

# ==============================================================================
# 7. EXPORTACIÓN
# ==============================================================================
# Ordenamiento Táctico: ID -> Tiempo -> Ataque -> Defensa
first_cols = ['player_name', 'nation', 'main_position_group', 'squad', 'league_id', 'age', 'record_type']
remaining = [c for c in df_export.columns if c not in first_cols]
df_export = df_export[first_cols + remaining]

df_export.to_csv(OUTPUT_FILE, index=False)

print("="*60)
print(f"✅ ÉXITO TOTAL: Base de Datos Elite generada.")
print(f"   Archivo: {OUTPUT_FILE}")
print(f"   Columnas Totales: {len(df_export.columns)}")
print("="*60)
# Out:
# >>> INICIANDO ETL V6: CON MAPEO ELITE (150 VARIABLES) <<<
# [1/5] Carga inicial: (2854, 267)
# [2/5] Sanitizando 140 métricas numéricas...
# [2.1/5] Aplicando correcciones manuales de edad para 8 jugadores...
#    -> Corregido: Olabade Aluko (Edad: 17, Nacido: 2006)
#    -> Corregido: Hannes Behrens (Edad: 19, Nacido: 2005)
#    -> Corregido: Pape Daouda Diongue (Edad: 18, Nacido: 2006)
#    -> Corregido: Jake Evans (Edad: 15, Nacido: 2008)
#    -> Corregido: Fer López (Edad: 20, Nacido: 2004)
#    -> Corregido: Mateus Mane (Edad: 16, Nacido: 2007)
#    -> Corregido: Max Moerstedt (Edad: 18, Nacido: 2006)
#    -> Corregido: Jeremy Monga (Edad: 15, Nacido: 2009)
# [2.2/5] Aplicando correcciones manuales de nacionalidad para jugadores específicos
#    -> Asignado ENG a Olabade Aluko
#    -> Asignado ENG a Jake Evans
#    -> Asignado TUR a Atakan Karazor
#    -> Asignado ESP a Fer López
#    -> Asignado POR a Mateus Mane
#    -> Asignado GER a Jeremy Monga
# ...
